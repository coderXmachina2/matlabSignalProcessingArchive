# %%
import datetime
import requests
import urllib

                                                   #Initialize Date
theTime = datetime.datetime(2013, 4, 4, 0, 0, 18) #year month day hour, minute, second 

#
#set naming index
index0 = 0
index1 = 0

print("Starting scrape operation: " + str(theTime) + " with index " + str(index0) + str(index1) + "\n")

#start iteration
for l in range(0,94): #download one day
    
    for p in range(0,150): #cycle through these seconds for a possible new image download
        
        #form download string
        theTime =  theTime + datetime.timedelta(0,1) #start increment at 1
        repString = str(theTime.year)+"/"+str(format(theTime.month, '02'))+"/"+str(format(theTime.day, '02'))+"/"+str(theTime.year)+str(format(theTime.month, '02'))+str(format(theTime.day, '02'))
        tReq = str(format(theTime.hour, '02')) + str(format(theTime.minute, '02')) + str(format(theTime.second, '02'))
        
        #this is the download String
        downloadString = "https://sdo.gsfc.nasa.gov/assets/img/browse/"+repString+"_" + tReq + "_1024_0171.jpg"
        
        request = requests.get(downloadString)
        if request.status_code == 200: #valid website
            print('Image at ' + downloadString +  ' exists. Downloading now.')
            folderString = "praiseTheSun/testDir" + str(index0) + str(index1) + ".jpg" #save directory
            myImage = urllib.request.urlretrieve(downloadString, folderString) #download successful
            print("Downloaded image " + str(index0) + str(index1) + "\n")
            index1 = index1 + 1
            theTime  = theTime + datetime.timedelta(0,790) #minimum jump 13 minutes 30 seconds
            
            break;

        else:
            print(str(p) + " Image at " + tReq + " does not exist. Increment")
# Out:
# Starting scrape operation: 2013-04-04 00:00:18 with index 00
#
# 0 Image at 000019 does not exist. Increment
# 1 Image at 000020 does not exist. Increment
# 2 Image at 000021 does not exist. Increment
# 3 Image at 000022 does not exist. Increment
# 4 Image at 000023 does not exist. Increment
# Image at https://sdo.gsfc.nasa.gov/assets/img/browse/2013/04/04/20130404_000024_1024_0171.jpg exists. Downloading now.
# Downloaded image 00
#
# 0 Image at 001335 does not exist. Increment
# 1 Image at 001336 does not exist. Increment
# 2 Image at 001337 does not exist. Increment
# 3 Image at 001338 does not exist. Increment
# 4 Image at 001339 does not exist. Increment
# 5 Image at 001340 does not exist. Increment
# 6 Image at 001341 does not exist. Increment
# 7 Image at 001342 does not exist. Increment
# 8 Image at 001343 does not exist. Increment
# 9 Image at 001344 does not exist. Increment
# 10 Image at 001345 does not exist. Increment
# 11 Image at 001346 does not exist. Increment
# 12 Image at 001347 does not exist. Increment
# 13 Image at 001348 does not exist. Increment
# 14 Image at 001349 does not exist. Increment
# 15 Image at 001350 does not exist. Increment
# 16 Image at 001351 does not exist. Increment
# 17 Image at 001352 does not exist. Increment
# 18 Image at 001353 does not exist. Increment
# 19 Image at 001354 does not exist. Increment
# 20 Image at 001355 does not exist. Increment
# 21 Image at 001356 does not exist. Increment
# 22 Image at 001357 does not exist. Increment
# 23 Image at 001358 does not exist. Increment
# 24 Image at 001359 does not exist. Increment
# 25 Image at 001400 does not exist. Increment
# 26 Image at 001401 does not exist. Increment
# 27 Image at 001402 does not exist. Increment
# 28 Image at 001403 does not exist. Increment
# 29 Image at 001404 does not exist. Increment
# 30 Image at 001405 does not exist. Increment
# 31 Image at 001406 does not exist. Increment
# 32 Image at 001407 does not exist. Increment
# 33 Image at 001408 does not exist. Increment
# 34 Image at 001409 does not exist. Increment
# 35 Image at 001410 does not exist. Increment
# 36 Image at 001411 does not exist. Increment
# 37 Image at 001412 does not exist. Increment
# 38 Image at 001413 does not exist. Increment
# 39 Image at 001414 does not exist. Increment
# 40 Image at 001415 does not exist. Increment
# 41 Image at 001416 does not exist. Increment
# 42 Image at 001417 does not exist. Increment
# 43 Image at 001418 does not exist. Increment
# 44 Image at 001419 does not exist. Increment
# 45 Image at 001420 does not exist. Increment
# 46 Image at 001421 does not exist. Increment
# 47 Image at 001422 does not exist. Increment
# 48 Image at 001423 does not exist. Increment
# 49 Image at 001424 does not exist. Increment
# 50 Image at 001425 does not exist. Increment
# 51 Image at 001426 does not exist. Increment
# 52 Image at 001427 does not exist. Increment
# 53 Image at 001428 does not exist. Increment
# 54 Image at 001429 does not exist. Increment
# 55 Image at 001430 does not exist. Increment
# 56 Image at 001431 does not exist. Increment
# 57 Image at 001432 does not exist. Increment
# 58 Image at 001433 does not exist. Increment
# 59 Image at 001434 does not exist. Increment
# 60 Image at 001435 does not exist. Increment
# 61 Image at 001436 does not exist. Increment
# 62 Image at 001437 does not exist. Increment
# 63 Image at 001438 does not exist. Increment
# 64 Image at 001439 does not exist. Increment
# 65 Image at 001440 does not exist. Increment
# 66 Image at 001441 does not exist. Increment
# 67 Image at 001442 does not exist. Increment
# 68 Image at 001443 does not exist. Increment
# 69 Image at 001444 does not exist. Increment
# 70 Image at 001445 does not exist. Increment
# 71 Image at 001446 does not exist. Increment
# 72 Image at 001447 does not exist. Increment
# Image at https://sdo.gsfc.nasa.gov/assets/img/browse/2013/04/04/20130404_001448_1024_0171.jpg exists. Downloading now.
# Downloaded image 01
#
# 0 Image at 002759 does not exist. Increment
# 1 Image at 002800 does not exist. Increment
# 2 Image at 002801 does not exist. Increment
# 3 Image at 002802 does not exist. Increment
# 4 Image at 002803 does not exist. Increment
# 5 Image at 002804 does not exist. Increment
# 6 Image at 002805 does not exist. Increment
# 7 Image at 002806 does not exist. Increment
# 8 Image at 002807 does not exist. Increment
# 9 Image at 002808 does not exist. Increment
# 10 Image at 002809 does not exist. Increment
# 11 Image at 002810 does not exist. Increment
# 12 Image at 002811 does not exist. Increment
# 13 Image at 002812 does not exist. Increment
# 14 Image at 002813 does not exist. Increment
# 15 Image at 002814 does not exist. Increment
# 16 Image at 002815 does not exist. Increment
# 17 Image at 002816 does not exist. Increment
# 18 Image at 002817 does not exist. Increment
# 19 Image at 002818 does not exist. Increment
# 20 Image at 002819 does not exist. Increment
# 21 Image at 002820 does not exist. Increment
# 22 Image at 002821 does not exist. Increment
# 23 Image at 002822 does not exist. Increment
# 24 Image at 002823 does not exist. Increment
# 25 Image at 002824 does not exist. Increment
# 26 Image at 002825 does not exist. Increment
# 27 Image at 002826 does not exist. Increment
# 28 Image at 002827 does not exist. Increment
# 29 Image at 002828 does not exist. Increment
# 30 Image at 002829 does not exist. Increment
# 31 Image at 002830 does not exist. Increment
# 32 Image at 002831 does not exist. Increment
# 33 Image at 002832 does not exist. Increment
# 34 Image at 002833 does not exist. Increment
# 35 Image at 002834 does not exist. Increment
# 36 Image at 002835 does not exist. Increment
# 37 Image at 002836 does not exist. Increment
# 38 Image at 002837 does not exist. Increment
# 39 Image at 002838 does not exist. Increment
# 40 Image at 002839 does not exist. Increment
# 41 Image at 002840 does not exist. Increment
# 42 Image at 002841 does not exist. Increment
# 43 Image at 002842 does not exist. Increment
# 44 Image at 002843 does not exist. Increment
# 45 Image at 002844 does not exist. Increment
# 46 Image at 002845 does not exist. Increment
# 47 Image at 002846 does not exist. Increment
# 48 Image at 002847 does not exist. Increment
# 49 Image at 002848 does not exist. Increment
# 50 Image at 002849 does not exist. Increment
# 51 Image at 002850 does not exist. Increment
# 52 Image at 002851 does not exist. Increment
# 53 Image at 002852 does not exist. Increment
# 54 Image at 002853 does not exist. Increment
# 55 Image at 002854 does not exist. Increment
# 56 Image at 002855 does not exist. Increment
# 57 Image at 002856 does not exist. Increment
# 58 Image at 002857 does not exist. Increment
# 59 Image at 002858 does not exist. Increment
# 60 Image at 002859 does not exist. Increment
# 61 Image at 002900 does not exist. Increment
# 62 Image at 002901 does not exist. Increment
# 63 Image at 002902 does not exist. Increment
# 64 Image at 002903 does not exist. Increment
# 65 Image at 002904 does not exist. Increment
# 66 Image at 002905 does not exist. Increment
# 67 Image at 002906 does not exist. Increment
# 68 Image at 002907 does not exist. Increment
# 69 Image at 002908 does not exist. Increment
# 70 Image at 002909 does not exist. Increment
# 71 Image at 002910 does not exist. Increment
# 72 Image at 002911 does not exist. Increment
# 73 Image at 002912 does not exist. Increment
# 74 Image at 002913 does not exist. Increment
# 75 Image at 002914 does not exist. Increment
# 76 Image at 002915 does not exist. Increment
# 77 Image at 002916 does not exist. Increment
# 78 Image at 002917 does not exist. Increment
# 79 Image at 002918 does not exist. Increment
# 80 Image at 002919 does not exist. Increment
# 81 Image at 002920 does not exist. Increment
# 82 Image at 002921 does not exist. Increment
# 83 Image at 002922 does not exist. Increment
# 84 Image at 002923 does not exist. Increment
# 85 Image at 002924 does not exist. Increment
# 86 Image at 002925 does not exist. Increment
# 87 Image at 002926 does not exist. Increment
# 88 Image at 002927 does not exist. Increment
# 89 Image at 002928 does not exist. Increment
# 90 Image at 002929 does not exist. Increment
# 91 Image at 002930 does not exist. Increment
# 92 Image at 002931 does not exist. Increment
# 93 Image at 002932 does not exist. Increment
# 94 Image at 002933 does not exist. Increment
# 95 Image at 002934 does not exist. Increment
# 96 Image at 002935 does not exist. Increment
# 97 Image at 002936 does not exist. Increment
# 98 Image at 002937 does not exist. Increment
# 99 Image at 002938 does not exist. Increment
# 100 Image at 002939 does not exist. Increment
# 101 Image at 002940 does not exist. Increment
# 102 Image at 002941 does not exist. Increment
# 103 Image at 002942 does not exist. Increment
# 104 Image at 002943 does not exist. Increment
# 105 Image at 002944 does not exist. Increment
# 106 Image at 002945 does not exist. Increment
# 107 Image at 002946 does not exist. Increment
# 108 Image at 002947 does not exist. Increment
# 109 Image at 002948 does not exist. Increment
# 110 Image at 002949 does not exist. Increment
# 111 Image at 002950 does not exist. Increment
# 112 Image at 002951 does not exist. Increment
# 113 Image at 002952 does not exist. Increment
# 114 Image at 002953 does not exist. Increment
# 115 Image at 002954 does not exist. Increment
# 116 Image at 002955 does not exist. Increment
# 117 Image at 002956 does not exist. Increment
# 118 Image at 002957 does not exist. Increment
# 119 Image at 002958 does not exist. Increment
# 120 Image at 002959 does not exist. Increment
# 121 Image at 003000 does not exist. Increment
# 122 Image at 003001 does not exist. Increment
# 123 Image at 003002 does not exist. Increment
# 124 Image at 003003 does not exist. Increment
# 125 Image at 003004 does not exist. Increment
# 126 Image at 003005 does not exist. Increment
# 127 Image at 003006 does not exist. Increment
# 128 Image at 003007 does not exist. Increment
# 129 Image at 003008 does not exist. Increment
# 130 Image at 003009 does not exist. Increment
# 131 Image at 003010 does not exist. Increment
# 132 Image at 003011 does not exist. Increment
# 133 Image at 003012 does not exist. Increment
# 134 Image at 003013 does not exist. Increment
# 135 Image at 003014 does not exist. Increment
# 136 Image at 003015 does not exist. Increment
# 137 Image at 003016 does not exist. Increment
# 138 Image at 003017 does not exist. Increment
# 139 Image at 003018 does not exist. Increment
# 140 Image at 003019 does not exist. Increment
# 141 Image at 003020 does not exist. Increment
# 142 Image at 003021 does not exist. Increment
# 143 Image at 003022 does not exist. Increment
# 144 Image at 003023 does not exist. Increment
# 145 Image at 003024 does not exist. Increment
# 146 Image at 003025 does not exist. Increment
# 147 Image at 003026 does not exist. Increment
# 148 Image at 003027 does not exist. Increment
# 149 Image at 003028 does not exist. Increment
# 0 Image at 003029 does not exist. Increment
# 1 Image at 003030 does not exist. Increment
# 2 Image at 003031 does not exist. Increment
# 3 Image at 003032 does not exist. Increment
# 4 Image at 003033 does not exist. Increment
# 5 Image at 003034 does not exist. Increment
# 6 Image at 003035 does not exist. Increment
# Image at https://sdo.gsfc.nasa.gov/assets/img/browse/2013/04/04/20130404_003036_1024_0171.jpg exists. Downloading now.
# Downloaded image 02
#
# 0 Image at 004347 does not exist. Increment
# 1 Image at 004348 does not exist. Increment
# 2 Image at 004349 does not exist. Increment
# 3 Image at 004350 does not exist. Increment
# 4 Image at 004351 does not exist. Increment
# 5 Image at 004352 does not exist. Increment
# 6 Image at 004353 does not exist. Increment
# 7 Image at 004354 does not exist. Increment
# 8 Image at 004355 does not exist. Increment
# 9 Image at 004356 does not exist. Increment
# 10 Image at 004357 does not exist. Increment
# 11 Image at 004358 does not exist. Increment
# 12 Image at 004359 does not exist. Increment
# 13 Image at 004400 does not exist. Increment
# 14 Image at 004401 does not exist. Increment
# 15 Image at 004402 does not exist. Increment
# 16 Image at 004403 does not exist. Increment
# 17 Image at 004404 does not exist. Increment
# 18 Image at 004405 does not exist. Increment
# 19 Image at 004406 does not exist. Increment
# 20 Image at 004407 does not exist. Increment
# 21 Image at 004408 does not exist. Increment
# 22 Image at 004409 does not exist. Increment
# 23 Image at 004410 does not exist. Increment
# 24 Image at 004411 does not exist. Increment
# 25 Image at 004412 does not exist. Increment
# 26 Image at 004413 does not exist. Increment
# 27 Image at 004414 does not exist. Increment
# 28 Image at 004415 does not exist. Increment
# 29 Image at 004416 does not exist. Increment
# 30 Image at 004417 does not exist. Increment
# 31 Image at 004418 does not exist. Increment
# 32 Image at 004419 does not exist. Increment
# 33 Image at 004420 does not exist. Increment
# 34 Image at 004421 does not exist. Increment
# 35 Image at 004422 does not exist. Increment
# 36 Image at 004423 does not exist. Increment
# 37 Image at 004424 does not exist. Increment
# 38 Image at 004425 does not exist. Increment
# 39 Image at 004426 does not exist. Increment
# 40 Image at 004427 does not exist. Increment
# 41 Image at 004428 does not exist. Increment
# 42 Image at 004429 does not exist. Increment
# 43 Image at 004430 does not exist. Increment
# 44 Image at 004431 does not exist. Increment
# 45 Image at 004432 does not exist. Increment
# 46 Image at 004433 does not exist. Increment
# 47 Image at 004434 does not exist. Increment
# 48 Image at 004435 does not exist. Increment
# 49 Image at 004436 does not exist. Increment
# 50 Image at 004437 does not exist. Increment
# 51 Image at 004438 does not exist. Increment
# 52 Image at 004439 does not exist. Increment
# 53 Image at 004440 does not exist. Increment
# 54 Image at 004441 does not exist. Increment
# 55 Image at 004442 does not exist. Increment
# 56 Image at 004443 does not exist. Increment
# 57 Image at 004444 does not exist. Increment
# 58 Image at 004445 does not exist. Increment
# 59 Image at 004446 does not exist. Increment
# 60 Image at 004447 does not exist. Increment
# 61 Image at 004448 does not exist. Increment
# 62 Image at 004449 does not exist. Increment
# 63 Image at 004450 does not exist. Increment
# 64 Image at 004451 does not exist. Increment
# 65 Image at 004452 does not exist. Increment
# 66 Image at 004453 does not exist. Increment
# 67 Image at 004454 does not exist. Increment
# 68 Image at 004455 does not exist. Increment
# 69 Image at 004456 does not exist. Increment
# 70 Image at 004457 does not exist. Increment
# 71 Image at 004458 does not exist. Increment
# 72 Image at 004459 does not exist. Increment
# 73 Image at 004500 does not exist. Increment
# 74 Image at 004501 does not exist. Increment
# 75 Image at 004502 does not exist. Increment
# 76 Image at 004503 does not exist. Increment
# 77 Image at 004504 does not exist. Increment
# 78 Image at 004505 does not exist. Increment
# 79 Image at 004506 does not exist. Increment
# 80 Image at 004507 does not exist. Increment
# 81 Image at 004508 does not exist. Increment
# 82 Image at 004509 does not exist. Increment
# 83 Image at 004510 does not exist. Increment
# 84 Image at 004511 does not exist. Increment
# 85 Image at 004512 does not exist. Increment
# 86 Image at 004513 does not exist. Increment
# 87 Image at 004514 does not exist. Increment
# 88 Image at 004515 does not exist. Increment
# 89 Image at 004516 does not exist. Increment
# 90 Image at 004517 does not exist. Increment
# 91 Image at 004518 does not exist. Increment
# 92 Image at 004519 does not exist. Increment
# 93 Image at 004520 does not exist. Increment
# 94 Image at 004521 does not exist. Increment
# 95 Image at 004522 does not exist. Increment
# 96 Image at 004523 does not exist. Increment
# Image at https://sdo.gsfc.nasa.gov/assets/img/browse/2013/04/04/20130404_004524_1024_0171.jpg exists. Downloading now.
# Downloaded image 03
#
# 0 Image at 005835 does not exist. Increment
# 1 Image at 005836 does not exist. Increment
# 2 Image at 005837 does not exist. Increment
# 3 Image at 005838 does not exist. Increment
# 4 Image at 005839 does not exist. Increment
# 5 Image at 005840 does not exist. Increment
# 6 Image at 005841 does not exist. Increment
# 7 Image at 005842 does not exist. Increment
# 8 Image at 005843 does not exist. Increment
# 9 Image at 005844 does not exist. Increment
# 10 Image at 005845 does not exist. Increment
# 11 Image at 005846 does not exist. Increment
# 12 Image at 005847 does not exist. Increment
# 13 Image at 005848 does not exist. Increment
# 14 Image at 005849 does not exist. Increment
# 15 Image at 005850 does not exist. Increment
# 16 Image at 005851 does not exist. Increment
# 17 Image at 005852 does not exist. Increment
# 18 Image at 005853 does not exist. Increment
# 19 Image at 005854 does not exist. Increment
# 20 Image at 005855 does not exist. Increment
# 21 Image at 005856 does not exist. Increment
# 22 Image at 005857 does not exist. Increment
# 23 Image at 005858 does not exist. Increment
# 24 Image at 005859 does not exist. Increment
# 25 Image at 005900 does not exist. Increment
# 26 Image at 005901 does not exist. Increment
# 27 Image at 005902 does not exist. Increment
# 28 Image at 005903 does not exist. Increment
# 29 Image at 005904 does not exist. Increment
# 30 Image at 005905 does not exist. Increment
# 31 Image at 005906 does not exist. Increment
# 32 Image at 005907 does not exist. Increment
# 33 Image at 005908 does not exist. Increment
# 34 Image at 005909 does not exist. Increment
# 35 Image at 005910 does not exist. Increment
# 36 Image at 005911 does not exist. Increment
# 37 Image at 005912 does not exist. Increment
# 38 Image at 005913 does not exist. Increment
# 39 Image at 005914 does not exist. Increment
# 40 Image at 005915 does not exist. Increment
# 41 Image at 005916 does not exist. Increment
# 42 Image at 005917 does not exist. Increment
# 43 Image at 005918 does not exist. Increment
# 44 Image at 005919 does not exist. Increment
# 45 Image at 005920 does not exist. Increment
# 46 Image at 005921 does not exist. Increment
# 47 Image at 005922 does not exist. Increment
# 48 Image at 005923 does not exist. Increment
# 49 Image at 005924 does not exist. Increment
# 50 Image at 005925 does not exist. Increment
# 51 Image at 005926 does not exist. Increment
# 52 Image at 005927 does not exist. Increment
# 53 Image at 005928 does not exist. Increment
# 54 Image at 005929 does not exist. Increment
# 55 Image at 005930 does not exist. Increment
# 56 Image at 005931 does not exist. Increment
# 57 Image at 005932 does not exist. Increment
# 58 Image at 005933 does not exist. Increment
# 59 Image at 005934 does not exist. Increment
# 60 Image at 005935 does not exist. Increment
# 61 Image at 005936 does not exist. Increment
# 62 Image at 005937 does not exist. Increment
# 63 Image at 005938 does not exist. Increment
# 64 Image at 005939 does not exist. Increment
# 65 Image at 005940 does not exist. Increment
# 66 Image at 005941 does not exist. Increment
# 67 Image at 005942 does not exist. Increment
# 68 Image at 005943 does not exist. Increment
# 69 Image at 005944 does not exist. Increment
# 70 Image at 005945 does not exist. Increment
# 71 Image at 005946 does not exist. Increment
# 72 Image at 005947 does not exist. Increment
# 73 Image at 005948 does not exist. Increment
# 74 Image at 005949 does not exist. Increment
# 75 Image at 005950 does not exist. Increment
# 76 Image at 005951 does not exist. Increment
# 77 Image at 005952 does not exist. Increment
# 78 Image at 005953 does not exist. Increment
# 79 Image at 005954 does not exist. Increment
# 80 Image at 005955 does not exist. Increment
# 81 Image at 005956 does not exist. Increment
# 82 Image at 005957 does not exist. Increment
# 83 Image at 005958 does not exist. Increment
# 84 Image at 005959 does not exist. Increment
# 85 Image at 010000 does not exist. Increment
# 86 Image at 010001 does not exist. Increment
# 87 Image at 010002 does not exist. Increment
# 88 Image at 010003 does not exist. Increment
# 89 Image at 010004 does not exist. Increment
# 90 Image at 010005 does not exist. Increment
# 91 Image at 010006 does not exist. Increment
# 92 Image at 010007 does not exist. Increment
# 93 Image at 010008 does not exist. Increment
# 94 Image at 010009 does not exist. Increment
# 95 Image at 010010 does not exist. Increment
# 96 Image at 010011 does not exist. Increment
# 97 Image at 010012 does not exist. Increment
# 98 Image at 010013 does not exist. Increment
# 99 Image at 010014 does not exist. Increment
# 100 Image at 010015 does not exist. Increment
# 101 Image at 010016 does not exist. Increment
# 102 Image at 010017 does not exist. Increment
# 103 Image at 010018 does not exist. Increment
# 104 Image at 010019 does not exist. Increment
# 105 Image at 010020 does not exist. Increment
# 106 Image at 010021 does not exist. Increment
# 107 Image at 010022 does not exist. Increment
# 108 Image at 010023 does not exist. Increment
# Image at https://sdo.gsfc.nasa.gov/assets/img/browse/2013/04/04/20130404_010024_1024_0171.jpg exists. Downloading now.
# Downloaded image 04
#
# 0 Image at 011335 does not exist. Increment
# 1 Image at 011336 does not exist. Increment
# 2 Image at 011337 does not exist. Increment
# 3 Image at 011338 does not exist. Increment
# 4 Image at 011339 does not exist. Increment
# 5 Image at 011340 does not exist. Increment
# 6 Image at 011341 does not exist. Increment
# 7 Image at 011342 does not exist. Increment
# 8 Image at 011343 does not exist. Increment
# 9 Image at 011344 does not exist. Increment
# 10 Image at 011345 does not exist. Increment
# 11 Image at 011346 does not exist. Increment
# 12 Image at 011347 does not exist. Increment
# 13 Image at 011348 does not exist. Increment
# 14 Image at 011349 does not exist. Increment
# 15 Image at 011350 does not exist. Increment
# 16 Image at 011351 does not exist. Increment
# 17 Image at 011352 does not exist. Increment
# 18 Image at 011353 does not exist. Increment
# 19 Image at 011354 does not exist. Increment
# 20 Image at 011355 does not exist. Increment
# 21 Image at 011356 does not exist. Increment
# 22 Image at 011357 does not exist. Increment
# 23 Image at 011358 does not exist. Increment
# 24 Image at 011359 does not exist. Increment
# 25 Image at 011400 does not exist. Increment
# 26 Image at 011401 does not exist. Increment
# 27 Image at 011402 does not exist. Increment
# 28 Image at 011403 does not exist. Increment
# 29 Image at 011404 does not exist. Increment
# 30 Image at 011405 does not exist. Increment
# 31 Image at 011406 does not exist. Increment
# 32 Image at 011407 does not exist. Increment
# 33 Image at 011408 does not exist. Increment
# 34 Image at 011409 does not exist. Increment
# 35 Image at 011410 does not exist. Increment
# 36 Image at 011411 does not exist. Increment
# 37 Image at 011412 does not exist. Increment
# 38 Image at 011413 does not exist. Increment
# 39 Image at 011414 does not exist. Increment
# 40 Image at 011415 does not exist. Increment
# 41 Image at 011416 does not exist. Increment
# 42 Image at 011417 does not exist. Increment
# 43 Image at 011418 does not exist. Increment
# 44 Image at 011419 does not exist. Increment
# 45 Image at 011420 does not exist. Increment
# 46 Image at 011421 does not exist. Increment
# 47 Image at 011422 does not exist. Increment
# 48 Image at 011423 does not exist. Increment
# 49 Image at 011424 does not exist. Increment
# 50 Image at 011425 does not exist. Increment
# 51 Image at 011426 does not exist. Increment
# 52 Image at 011427 does not exist. Increment
# 53 Image at 011428 does not exist. Increment
# 54 Image at 011429 does not exist. Increment
# 55 Image at 011430 does not exist. Increment
# 56 Image at 011431 does not exist. Increment
# 57 Image at 011432 does not exist. Increment
# 58 Image at 011433 does not exist. Increment
# 59 Image at 011434 does not exist. Increment
# 60 Image at 011435 does not exist. Increment
# 61 Image at 011436 does not exist. Increment
# 62 Image at 011437 does not exist. Increment
# 63 Image at 011438 does not exist. Increment
# 64 Image at 011439 does not exist. Increment
# 65 Image at 011440 does not exist. Increment
# 66 Image at 011441 does not exist. Increment
# 67 Image at 011442 does not exist. Increment
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1906         result = _lib.SSL_do_handshake(self._ssl)
# -> 1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1631                         raise SysCallError(errno, errorcode.get(errno))
# -> 1632                 raise SysCallError(-1, "Unexpected EOF")
#    1633             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     458             except OpenSSL.SSL.Error as e:
# --> 459                 raise ssl.SSLError('bad handshake: %r' % e)
#     460             break
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='sdo.gsfc.nasa.gov', port=443): Max retries exceeded with url: /assets/img/browse/2013/04/04/20130404_011443_1024_0171.jpg (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-4-73a02132793d> in <module>
#      23         downloadString = "https://sdo.gsfc.nasa.gov/assets/img/browse/"+repString+"_" + tReq + "_1024_0171.jpg"
#      24
# ---> 25         request = requests.get(downloadString)
#      26         if request.status_code == 200: #valid website
#      27             print('Image at ' + downloadString +  ' exists. Downloading now.')
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='sdo.gsfc.nasa.gov', port=443): Max retries exceeded with url: /assets/img/browse/2013/04/04/20130404_011443_1024_0171.jpg (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))

# %%
import datetime

                                                   #Initialize Date
theTime = datetime.datetime(2013, 4, 15, 0, 0, 0) #year month day hour, minute, second 
print("Starting scrape operation: " + str(theTime))
# Out:
# Starting scrape operation: 2013-04-15 00:00:00

# %%
"2013/02/21/20130221"
# Out:
# '2013/02/21/20130221'

# %%
repString = str(theTime.year)+"/"+str(format(theTime.month, '02'))+"/"+str(theTime.day)+"/"+str(theTime.year)+str(theTime.month)+str(theTime.day)
repString
# Out:
# '2013/04/15/2013415'
